# %% [markdown]
# <a href="https://colab.research.google.com/github/Carlos051068/Colab_aula_Anhanguera/blob/main/introducao_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#https://www.youtube.com/watch?v=C0aj3FjN5e0
#Introdução ao Pandas no Python - [SAIA DO ZERO EM 1 AULA]

#https://olinda.bcb.gov.br/olinda/servico/mecir_dinheiro_em_circulacao/versao/v1/odata/informacoes_diarias?$top=100&$format=json&$select=Quantidade,Denominacao,Especie

import pandas as pd

#dinheiroemcirculacao_df = pd.DataFrame(dinheiroemcirculacao)
#print mostra em formato de texto
#display mostra formatado
dinheiroemcirculacao_df = pd.read_json("https://olinda.bcb.gov.br/olinda/servico/mecir_dinheiro_em_circulacao/versao/v1/odata/informacoes_diarias?$top=10&$format=json&$select=Quantidade,Denominacao,Especie")
#display(dinheiroemcirculacao_df)
display(dinheiroemcirculacao_df.head(10))#mostra as 10 primeiras linhas
display(dinheiroemcirculacao_df.shape)#mostra quantidade de linha e colunas
display(dinheiroemcirculacao_df.describe())#mostra um resumo
#print(dinheiroemcirculacao_df)

#pd.read_json("https://olinda.bcb.gov.br/olinda/servico/mecir_dinheiro_em_circulacao/versao/v1/odata/informacoes_diarias?$top=10&$format=json&$select=Quantidade,Denominacao,Especie").head()
# Out:
#                                       @odata.context  \
# 0  https://was-p.bcnet.bcb.gov.br/olinda/servico/...
# 1  https://was-p.bcnet.bcb.gov.br/olinda/servico/...
# 2  https://was-p.bcnet.bcb.gov.br/olinda/servico/...
# 3  https://was-p.bcnet.bcb.gov.br/olinda/servico/...
# 4  https://was-p.bcnet.bcb.gov.br/olinda/servico/...
# 5  https://was-p.bcnet.bcb.gov.br/olinda/servico/...
# 6  https://was-p.bcnet.bcb.gov.br/olinda/servico/...
# 7  https://was-p.bcnet.bcb.gov.br/olinda/servico/...
# 8  https://was-p.bcnet.bcb.gov.br/olinda/servico/...
# 9  https://was-p.bcnet.bcb.gov.br/olinda/servico/...
#
#                                                value
# 0  {'Quantidade': 692701959, 'Denominacao': '0.01...
# 1  {'Quantidade': 462277579, 'Denominacao': '0.05...
# 2  {'Quantidade': 404559065, 'Denominacao': '0.10...
# 3  {'Quantidade': 1492870, 'Denominacao': '0.25',...
# 4  {'Quantidade': 278901842, 'Denominacao': '0.50...
# 5  {'Quantidade': 267853898, 'Denominacao': '1.00...
# ...

# %%
#pegar uma linha (É uma série do pandas)
display(dinheiroemcirculacao_df.loc[1]) #[1:3] imprimi até a linha 3
#display(dinheiroemcirculacao_df.loc[dinheiroemcirculacao_df['ID Loja'] == 'Norte Shopping']) #imprimi com condição

#dinheiroemcirculacao_df = dinheiroemcirculacao_df.loc[dinheiroemcirculacao_df['ID Loja'] == 'Norte Shopping',["ID Loja","Produto","Quantidade"]]
#display(dinheiroemcirculacao_df)

#PEGAR UM VALOR ESPECÍFICO
#print(dinheiroemcirculacao_df.loc[1,'Produto'])
# Out:
# @odata.context    https://was-p.bcnet.bcb.gov.br/olinda/servico/...
# value             {'Quantidade': 462277579, 'Denominacao': '0.05...
# Name: 1, dtype: object
