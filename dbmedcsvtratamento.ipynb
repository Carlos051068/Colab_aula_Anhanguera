# %% [markdown]
# <a href="https://colab.research.google.com/github/Carlos051068/Colab_aula_Anhanguera/blob/main/dbmedcsvtratamento.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#https://www.youtube.com/watch?v=rVJW-rgJUkY&t=1339
#Anhanguera
#Como Tratar Valores Vazios em uma Base de Dados com Python
import pandas as pd
import numpy as np

informacao_df = pd.read_csv('bdmed192021.csv') #importar arquivo bdmed192021.csv para COLAB

display(informacao_df.head(5))#mostra as 10 primeiras linhas
print('*QUANTIDADE DE LINHAS*'*2)
display(informacao_df.shape)#mostra quantidade de linha e colunas
print('*RESUMO*'*10)
display(informacao_df.describe())#mostra um resumo
print('*RESUMO*'*10)
print(''*90)
print('*INFORMAÇÃO*'*5)
display(informacao_df.info())#mostra informações dos dados
print('+INFORMAÇÃO'*5)
print('-'*90)
print('*(DF_ISNA().ANY())*'*3)
display(informacao_df.isna().any()) #mostra valores vazios = True
print('|(DF_ISNA().ANY()) vazio=True*'*3)
print('-'*90)
print('*(DF_ISNA().SUM()) soma vazios*'*3)
display(informacao_df.isna().sum()) #SOMA valores vazios
print('|(DF_ISNA().SUM()) soma vazio*'*3)


print('-'*90)
print('excluir coluna vazias')
# ex vendas_df = vendas_df.dropna(how='all', axis=1) deleta linha/coluna completamente vazias
# axis= 1 exclui coluna 0 exclui linha
# how= all todos | how=any alguns

#vendas_df = vendas_df.dropna() deleta linha que possuem pelo menos 1 valor vazio

# preencher com valor vazio / preencher com a média da coluna
#vendas_df['COMISSAO']= vendas_df['comissao].fillna(vendas_df['cOMISSAO'].mean()) 

#vendas_df['COMISSAO']= vendas_df['comissao'].fillna(1) #(1) preenche com 1
#vendas_df = vendas_df.ffill() preencher com o último valor

#informacao_df['Patologista Alocado']= informacao_df['Patologista Alocado'].fillna(method='ffill')
#display(informacao_df)

#informacao_df['Encerramento']= informacao_df['Encerramento'].fillna(method='ffill')
#informacao_df['Patologista Alocado']= informacao_df['Patologista Alocado'].fillna(method='ffill')
#informacao_df['Encerramento']= informacao_df['Encerramento'].interpolate()

#MESCLAR TABELAS
#vendas_df = vendas_df.merge((gerentes_df))

# %%
informacao_df['Encerramento']= informacao_df['Encerramento'].fillna(method='ffill')

display(informacao_df)
print('*(DF_ISNA().ANY())*'*3)
display(informacao_df.isna().any()) #mostra valores vazios = True
print('|(DF_ISNA().ANY()) vazio=True*'*3)
print('-'*90)
# Out:
#                 Número     Entrada Encerramento  Espera  \
# 0      1901-00001       2019/01/02   2019/01/08       4
# 1      1901-00002       2019/01/02   2019/01/09       5
# 2      1901-00003       2019/01/02   2019/01/09       5
# 3      1901-00004       2019/01/02   2019/01/08       4
# 4      1901-00005       2019/01/02   2019/01/04       2
# ...                ...         ...          ...     ...
# 70626  2151-00191       2021/04/01   2021/04/01       2
# 70627  2151-00192       2021/04/01   2021/04/01       2
# 70628  2151-00193       2021/04/01   2021/04/01       2
# 70629  2151-00194       2021/04/01   2021/04/01       2
# 70630  2152-00001       2021/03/10   2021/03/17       5
#
#                       Situação           Tipo Exame  \
# 0      IntegradoSistemaExterno  Patologia Cirúrgica
# 1      IntegradoSistemaExterno  Patologia Cirúrgica
# 2      IntegradoSistemaExterno  Patologia Cirúrgica
# 3      IntegradoSistemaExterno  Patologia Cirúrgica
# 4      IntegradoSistemaExterno  Patologia Cirúrgica
# ...                        ...                  ...
# 70626              Microscopia  Patologia Cirúrgica
# 70627              Microscopia  Patologia Cirúrgica
# 70628              Microscopia  Patologia Cirúrgica
# 70629              Microscopia  Patologia Cirúrgica
# 70630  IntegradoSistemaExterno           Citologias
#
#                                       Exame Origem  Usuario Prioridade  \
# 0      01 - ANATOMOPATOLOGICO PEÇAS GRANDES   HNSC   oliria     Rotina
# 1            01 - ANATOMOPATOLOGICO BIOPSIA   HNSC   oliria     Rotina
# 2      01 - ANATOMOPATOLOGICO PEÇAS GRANDES   HNSC   oliria     Rotina
# 3      01 - ANATOMOPATOLOGICO PEÇAS GRANDES   HNSC   oliria     Rotina
# 4            01 - ANATOMOPATOLOGICO BIOPSIA   HNSC   oliria    Urgente
# ...                                     ...    ...      ...        ...
# 70626     51 - REVISÃO DE ANATOMOPATOLOGICO    HFE  liliana     Rotina
# 70627     51 - REVISÃO DE ANATOMOPATOLOGICO    HFE  luciana     Rotina
# 70628     51 - REVISÃO DE ANATOMOPATOLOGICO   HNSC  luciana     Rotina
# 70629     51 - REVISÃO DE ANATOMOPATOLOGICO   HNSC  luciana     Rotina
# 70630        52 - REVISÃO DE CITOPATOLÓGICO   HNSC  luciana    Urgente
#
#                 Patologista Alocado  Quantidade de Blocos  Mês   Ano
# 0             Dr. Eduardo Cambruzzi                    12    1  2019
# 1             Dr. Eduardo Cambruzzi                     1    1  2019
# 2             Dr. Eduardo Cambruzzi                     6    1  2019
# 3        Dra. Silvia Chaves e Silva                     2    1  2019
# 4           Dra. Jane Maria Ulbrich                     2    1  2019
# ...                             ...                   ...  ...   ...
# 70626         Dr. Eduardo Cambruzzi                     0    4  2021
# 70627         Dr. Eduardo Cambruzzi                     0    4  2021
# 70628       Dr. Eduardo Lahude Lima                     0    4  2021
# 70629       Dr. Eduardo Lahude Lima                     0    4  2021
# 70630  Dra. Deise Regina Maffazzoni                     0    3  2021
#
# [70631 rows x 14 columns]
# *(DF_ISNA().ANY())**(DF_ISNA().ANY())**(DF_ISNA().ANY())*
# Número                  False
# Entrada                 False
# Encerramento            False
# Espera                  False
# Situação                False
# Tipo Exame              False
# Exame                   False
# Origem                  False
# Usuario                 False
# Prioridade              False
# Patologista Alocado     False
# Quantidade de Blocos    False
# Mês                     False
# Ano                     False
# dtype: bool
# |(DF_ISNA().ANY()) vazio=True*|(DF_ISNA().ANY()) vazio=True*|(DF_ISNA().ANY()) vazio=True*
# ------------------------------------------------------------------------------------------

# %%
informacao_df['Patologista Alocado']= informacao_df['Patologista Alocado'].fillna(method='ffill')
display(informacao_df)
print('*(DF_ISNA().ANY())*'*3)
display(informacao_df.isna().any()) #mostra valores vazios = True
print('|(DF_ISNA().ANY()) vazio=True*'*3)
print('-'*90)
# Out:
#                 Número     Entrada Encerramento  Espera  \
# 0      1901-00001       2019/01/02   2019/01/08       4
# 1      1901-00002       2019/01/02   2019/01/09       5
# 2      1901-00003       2019/01/02   2019/01/09       5
# 3      1901-00004       2019/01/02   2019/01/08       4
# 4      1901-00005       2019/01/02   2019/01/04       2
# ...                ...         ...          ...     ...
# 70626  2151-00191       2021/04/01   2021/04/01       2
# 70627  2151-00192       2021/04/01   2021/04/01       2
# 70628  2151-00193       2021/04/01   2021/04/01       2
# 70629  2151-00194       2021/04/01   2021/04/01       2
# 70630  2152-00001       2021/03/10   2021/03/17       5
#
#                       Situação           Tipo Exame  \
# 0      IntegradoSistemaExterno  Patologia Cirúrgica
# 1      IntegradoSistemaExterno  Patologia Cirúrgica
# 2      IntegradoSistemaExterno  Patologia Cirúrgica
# 3      IntegradoSistemaExterno  Patologia Cirúrgica
# 4      IntegradoSistemaExterno  Patologia Cirúrgica
# ...                        ...                  ...
# 70626              Microscopia  Patologia Cirúrgica
# 70627              Microscopia  Patologia Cirúrgica
# 70628              Microscopia  Patologia Cirúrgica
# 70629              Microscopia  Patologia Cirúrgica
# 70630  IntegradoSistemaExterno           Citologias
#
#                                       Exame Origem  Usuario Prioridade  \
# 0      01 - ANATOMOPATOLOGICO PEÇAS GRANDES   HNSC   oliria     Rotina
# 1            01 - ANATOMOPATOLOGICO BIOPSIA   HNSC   oliria     Rotina
# 2      01 - ANATOMOPATOLOGICO PEÇAS GRANDES   HNSC   oliria     Rotina
# 3      01 - ANATOMOPATOLOGICO PEÇAS GRANDES   HNSC   oliria     Rotina
# 4            01 - ANATOMOPATOLOGICO BIOPSIA   HNSC   oliria    Urgente
# ...                                     ...    ...      ...        ...
# 70626     51 - REVISÃO DE ANATOMOPATOLOGICO    HFE  liliana     Rotina
# 70627     51 - REVISÃO DE ANATOMOPATOLOGICO    HFE  luciana     Rotina
# 70628     51 - REVISÃO DE ANATOMOPATOLOGICO   HNSC  luciana     Rotina
# 70629     51 - REVISÃO DE ANATOMOPATOLOGICO   HNSC  luciana     Rotina
# 70630        52 - REVISÃO DE CITOPATOLÓGICO   HNSC  luciana    Urgente
#
#                 Patologista Alocado  Quantidade de Blocos  Mês   Ano
# 0             Dr. Eduardo Cambruzzi                    12    1  2019
# 1             Dr. Eduardo Cambruzzi                     1    1  2019
# 2             Dr. Eduardo Cambruzzi                     6    1  2019
# 3        Dra. Silvia Chaves e Silva                     2    1  2019
# 4           Dra. Jane Maria Ulbrich                     2    1  2019
# ...                             ...                   ...  ...   ...
# 70626         Dr. Eduardo Cambruzzi                     0    4  2021
# 70627         Dr. Eduardo Cambruzzi                     0    4  2021
# 70628       Dr. Eduardo Lahude Lima                     0    4  2021
# 70629       Dr. Eduardo Lahude Lima                     0    4  2021
# 70630  Dra. Deise Regina Maffazzoni                     0    3  2021
#
# [70631 rows x 14 columns]
# *(DF_ISNA().ANY())**(DF_ISNA().ANY())**(DF_ISNA().ANY())*
# Número                  False
# Entrada                 False
# Encerramento            False
# Espera                  False
# Situação                False
# Tipo Exame              False
# Exame                   False
# Origem                  False
# Usuario                 False
# Prioridade              False
# Patologista Alocado     False
# Quantidade de Blocos    False
# Mês                     False
# Ano                     False
# dtype: bool
# |(DF_ISNA().ANY()) vazio=True*|(DF_ISNA().ANY()) vazio=True*|(DF_ISNA().ANY()) vazio=True*
# ------------------------------------------------------------------------------------------
