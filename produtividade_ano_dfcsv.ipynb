# %% [markdown]
# <a href="https://colab.research.google.com/github/Carlos051068/Colab_aula_Anhanguera/blob/main/produtividade_ano_dfcsv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#https://www.youtube.com/watch?v=L50fiScthSc
#Como manipular um DataFrame e EXPORTAR para CSV? | Análise de dados #9

import matplotlib.pyplot as plt
import numpy as np
import matplotlib
import pandas as pd

produtividade_ano_df = pd.read_csv('Produtividade_ano.csv', sep=';')

display(produtividade_ano_df.head(40))#mostra as 10 primeiras linhas
display(produtividade_ano_df.shape)#mostra quantidade de linha e colunas
display(produtividade_ano_df.describe())#mostra um resumo
#produtividade_ano_df['Ano']= produtividade_ano_df['Ano'].astype(datetime format=%y%)
print('TIPO DE DADO -'*3)
produtividade_ano_df.dtypes # exibe o tipo de cada coluna
print(produtividade_ano_df.dtypes)
print('TIPO DE DADO -'*3)

print("H"*90)
#print('CALCULAR INDICADORES utilizando values_counts EXAME/ANO')
#produtividade_ano_df = produtividade_ano[['Exame','Ano']].value_counts()
#display(produtividade_ano_df)
# Out:
#                                                 Exame   Ano  Quantidade
# 0                      01 - ANATOMOPATOLOGICO BIOPSIA  2019       12616
# 1                      01 - ANATOMOPATOLOGICO BIOPSIA  2020       10225
# 2                      22 - CITOLOGIA CÉRVICO-VAGINAL  2019        8524
# 3               01 - ANATOMOPATOLOGICO PEÇAS PEQUENAS  2019        6489
# 4                      22 - CITOLOGIA CÉRVICO-VAGINAL  2020        4302
# 5                      01 - ANATOMOPATOLOGICO BIOPSIA  2021        3766
# 6               01 - ANATOMOPATOLOGICO PEÇAS PEQUENAS  2020        3757
# 7                01 - ANATOMOPATOLOGICO PEÇAS GRANDES  2019        3746
# 8   02 - CITOPATOLOGIA ONCÓTICA (EXCETO CÉRVICO-VA...  2019        2621
# 9                01 - ANATOMOPATOLOGICO PEÇAS GRANDES  2020        2528
# 10  02 - CITOPATOLOGIA ONCÓTICA (EXCETO CÉRVICO-VA...  2020        1899
# 11                  07 - IMUNOHISTOQUIMICA(EXCETO RH)  2020        1723
# ...
