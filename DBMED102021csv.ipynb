# %% [markdown]
# <a href="https://colab.research.google.com/github/Carlos051068/Colab_aula_Anhanguera/blob/main/DBMED102021csv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#https://www.youtube.com/watch?v=yV2BCFvXmC8
#Anhanguera
#Como importar arquivos .CSV para seu projeto Google Colab, Jupyter Notebook ou Spider

import pandas as pd

pd.read_csv('bdmed192021.csv') #importar arquivo bdmed192021.csv para COLAB
# Out:
#                 Número     Entrada Encerramento  Espera  \
# 0      1901-00001       2019/01/02   2019/01/08       4
# 1      1901-00002       2019/01/02   2019/01/09       5
# 2      1901-00003       2019/01/02   2019/01/09       5
# 3      1901-00004       2019/01/02   2019/01/08       4
# 4      1901-00005       2019/01/02   2019/01/04       2
# ...                ...         ...          ...     ...
# 70626  2151-00191       2021/04/01          NaN       2
# 70627  2151-00192       2021/04/01          NaN       2
# 70628  2151-00193       2021/04/01          NaN       2
# 70629  2151-00194       2021/04/01          NaN       2
# 70630  2152-00001       2021/03/10   2021/03/17       5
#
#                       Situação           Tipo Exame  \
# 0      IntegradoSistemaExterno  Patologia Cirúrgica
# 1      IntegradoSistemaExterno  Patologia Cirúrgica
# 2      IntegradoSistemaExterno  Patologia Cirúrgica
# 3      IntegradoSistemaExterno  Patologia Cirúrgica
# ...
